# %% [markdown]
# <div style="text-align: center;">
# <h2>INFSCI 2915 Foundations- Machine Learning - Spring 2018 </h2>
# <h1 style="font-size: 250%;">Assignment #3</h1>
# <h3>Issued Monday, 3/26/2018; Due Monday, 11:59pm, 4/09/2018</h3>
# <h3>Total points: 100 </h3>
# </div>

# %%
# Type in your information in the double quotes
firstName = "Ankur"
lastName = "Nadda"
pittID = "ann69"

# %% [markdown]
# <h3>  Problem #1.Linear Discriminant Analysis (LDA)and Quadratic Discriminant Analysis(QDA)      <br>[30 points]</h3>
#  Writing a code is not required for this problem.

# %% [markdown]
# <h4> Problem #1-1</h4>  <br>
# Assume we have K classes to be classified with one feature $(x)$. The prior probability of
# class $k$ is $𝜋_{k} = 𝑃(𝑌 = 𝑘)$. Assume that the feature in class k has Gaussian distribution of
# mean $μ_{k}$ and variance $σ^2 (𝒩(μ,𝜎^{2}))$.The variance is the same for all classes.
# Prove that the Bayes’ classifier (that chooses class k with largest $𝑃(𝑌 = 𝑘|𝑥))$ is equivalent to assigning an observation to the class for which the discriminant function $𝛿_{k}(x)$ is
# maximized, where
# \begin{array} \\
# 𝛿_{k}(x) = x\frac{\mu _{k}}{\sigma ^{2}}- \frac{\mu_{2}^{k}}{2\sigma ^{2}}+ log(\pi _{k})
# \end{array}
# <br> What is the name of this classifier?

# %% [markdown]
# ![1.jpg](attachment:1.jpg)

# %% [markdown]
# The classifier is LDA, as done in proof, final maximization function of $𝛿_{k}(x)$

# %% [markdown]
# <h4> Problem #1-2</h4>  <br>
# Extend **Problem #1-1** to include **p** features. With features from each class drawn from a
# Gaussian distribution with mean vector $μ_{k}$ and covariance matrix $Σ_{k}$ (which is now
# different for each class). Find the discriminant function that maximizes **𝑃(𝑌 = 𝑘|𝑥)**. Is
# the relationship with the feature vector **x** linear?<br> What is this classifier?

# %% [markdown]
# ![cf00460d-eedb-4af8-a1ed-6ccfca8784bb.jpg](attachment:cf00460d-eedb-4af8-a1ed-6ccfca8784bb.jpg)

# %% [markdown]
# The function is not linear with feature vector in x, the classifier is QDA

# %% [markdown]
# <h4> Problem #1-3</h4>  <br>
# - Explain Bias-variance trade-off in choosing between LDA and QDA

# %% [markdown]
# With p predictors, estimating a co variance matrix requires estimating p(p+1)/2 parameters. The QDA estimates a separate co variance matrix for each class, so as the number of predictors becomes high, we experience a computational expense. Conversely, if we assume a common co variance matrix, we only have to do the computation once. LDA is a much less flexible classifier, than QDA, thus has substantially lower variance. However, if the assumption of uniform variance is highly off, then LDA can suffer high bias. In general, LDA tends to be better than QDA if there are relatively few training observations, so therefore reducing variance is crucial. QDA is recommended if the training set is very large, so that the variance of the classifier is not a major concern.

# %% [markdown]
# <h3>  Problem #2. Support Vector Machines  [20 points]</h3>
# Writing a code is not required for this problem.

# %% [markdown]
# <h4> Problem #2-1 Answer the following quesionts </h4>
#
# - Describe limitations of using Maximal Margin Classifier
# - What is the difference between Support Vector Classifier and Maximal Margin Classifier
# - Explain Bias-variance trade-off that occurs when we choose large and small values for the Slack Variables

# %% [markdown]
# <b>Limitations of using Maximal Margin Classifier:</b>
#
# Maximal margin classifier is a very natural way to perform classification, is a separating hyperplane exists. However existence of such a hyperplane may not be guaranteed, or even if it exists, the data is noisy so that maximal margin classifier provides a poor solution. If a new data point is added the decision boundary changes drastically
#
# The maximum margin classifier depends on the support vectors and not on other training observations, hence hope is that largest margin on training data will also work well on test data.
#
# Assumes that the classes can be perfectly separable, which is not always the case.

# %% [markdown]
# <b>Difference between SVC and MMC:</b>
#
# The generalization of the maximal margin classifier to the non-separable case is known as the support vector classifier, where a small proportion of the training sample is allowed to cross the margins, or even the separating hyperplane.
#
# Rather than looking for the largest possible margin so that every observation is on the correct side of the margin, thereby making the margins very narrow or non-existent, some observations are allowed to be on the incorrect side of the margins. The margin is soft as a small number of observations violate the margin. The softness is controlled by slack variables which control the position of the observations relative to the margins and separating hyperplane.

# %% [markdown]
# <b> Impact of Slack Variables </b>
#
# Large:
# – Allow for more violation of margin
# – More support vectors
# – Less variance, more stable
# – Potential high bais
#
# Small:
# – less violation on training data allowed
# – Low training training error, less bias
# – Fewer support vectors
# – Higher variance

# %% [markdown]
# <h4> Problem #2-2</h4><br>
# How does the Radial Basis Function Kernel in SVM measure the similarity between a test point and a training example? Discuss the impact of choosing a large RBF parameter **𝛾**
# on the learning algorithm.

# %% [markdown]
# #Write your narrative answer here (no code is needed for this part)
# RBF computed the euclidean distance between the observation point and the training point to compute its similarity. It uses Gaussian like similarity measure. Large **𝛾** may overfit because it becomes more local, has small variance.

# %% [markdown]
# <h3>  Problem #3 Classification Performance Evaluation and Cross validation [30 points]</h3>

# %% [markdown]
# <h4> Problem #3-1</h4> <br>
# In a fraud detection system, a QDA classifier’s confusion matrix is found to be:

# %% [markdown]
# |        |Predicted Class - Not fraud| Predicted Class - fraud|
# |:--:|:-------------------------------:|
# |Actual class – Not fraud|1000|20|
# |Actual class – fraud|30|5|

# %% [markdown]
# - Evaluate the overall error rate and the accuracy<br>
# - Evaluate the precision and the recall <br>
# - Is dataset balanced?
# - Comment on the results.

# %%
print("True Positive: 1000")
print("True Negative: 5")
print("False Positive: 20")
print("False Negative: 30")
accuracy = (1005/1055)
error_rate = 1 - accuracy
print("Accuracy is ", accuracy)
print("Error Rate is ", error_rate)
precision = (5/25)
recall = (5/35)
print("Precision is ", precision)
print("Recall is ", recall)
# Out:
# True Positive: 1000
# True Negative: 5
# False Positive: 20
# False Negative: 30
# Accuracy is  0.95260663507109
# Error Rate is  0.04739336492891
# Precision is  0.2
# Recall is  0.14285714285714285

# %% [markdown]
# The dataset consists of Skewed classes (dataset is not balanced): there is no sufficient training examples for one of the classes. Hence accuracy and error rate are not the best measures for such dataset. Other measure reflect the performance better.

# %% [markdown]
# <h4> Problem #3-2</h4> <br>
# Assuming we want to lower the misclassification of fraud. How can you modify the classifier to do better classification using information from confusion matrix?

# %% [markdown]
# By understanding the performance better through the confusion matrix, we can modify the classifier to go better job based on the requirement. We can modify the classifier by changing the 0.5 threshold.

# %% [markdown]
# <h4> Problem #3-3 Cross validation, SVM </h4> <br>
# In this exercise, we will use SVM  for breast cancer classification (malignant or benign).<br>
# Use a code below to download the dataset:

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
dataset = load_breast_cancer()
print(dataset.keys())
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names'])

# %% [markdown]
# Follow steps to answer questions.
# - Scale the features with MinMaxScaler
# - Split breast cancer dataset into two, test dataset and train dataset
# - Find best SVM classifier model. Try values of C=[0.001, 0.1, 1, 10, 1000] and Gamma = [0.001, 0.1, 1, 10, 1000].
# - Use 3-fold cross validation to find the best parameters (using all possible combinations of these values for C and gamma).
# - Report your parameters
# - Report accuracy, confusion matrix, precision, and recall (use Test dataset, SVM classifier model with best parameters)
# - Comment your results

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix, precision_score, recall_score
import itertools
import matplotlib.pyplot as plt
import numpy as np

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

kfolds = 3
c = [0.001, 0.1, 1, 10, 1000]
g = [0.001, 0.1, 1, 10, 1000]
bestScore = 0
data = dataset.data
scaler = MinMaxScaler()
scaler.fit(data)
scaler.data_max_
scaled_data = scaler.transform(data)
X_train, X_test, Y_train, Y_test = train_test_split(scaled_data, dataset.target, random_state=0)
for i in range(0, 5):
    svmModel = SVC(kernel='rbf', gamma=g[i], C=c[i])
    scores = cross_val_score(svmModel, X_train, Y_train, cv=kfolds)
    score = np.mean(scores)
    if score > bestScore:
        bestScore = score
        bestParameter = c[i]
        bestGama = g[i]
FinalsvmModel = SVC(kernel='rbf', gamma=bestGama, C=bestParameter).fit(X_train, Y_train)
test_score = FinalsvmModel.score(X_test,Y_test)
PredictedOutput = FinalsvmModel.predict(X_test) 
print("Best Score on train set", bestScore)
print("Best Parameter ", bestParameter)
print("Best Gamma ", bestGama)
print("Score of SVM ", test_score)
confusion=confusion_matrix(Y_test,PredictedOutput)
plt.figure()
plot_confusion_matrix(confusion, classes=dataset.target_names,title='Confusion matrix')
plt.show()
print("Precision ", precision_score(Y_test,PredictedOutput))
print("Recall ", recall_score(Y_test,PredictedOutput))
print("-------------------------")
# Out:
# Best Score on train set 0.978873239437
# Best Parameter  1
# Best Gamma  1
# Score of SVM  0.972027972028
# Precision  0.967391304348
# Recall  0.988888888889
# -------------------------

# %% [markdown]
# Cross validation gives us the optimal parameters and gamma for the SVM model which reflects best scores

# %% [markdown]
# <h4> Problem #3-4 Cross validation, Logistic regression </h4>
#
# - Repeat **Problem #3-3** but instead of SVM find best Logistic regression classifier model. Try values of C= [0.001,0.01,1,10,100, 1000] and Penalty = ["l1","l2"]

# %%
#Write your answer here
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix, precision_score, recall_score
import itertools
import matplotlib.pyplot as plt
import numpy as np

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

kfolds = 3
c = [0.001,0.01,1,10,100, 1000] 
penalty = ["l1", "l2"]
bestScore = 0
data = dataset.data
scaler = MinMaxScaler()
scaler.fit(data)
scaler.data_max_
scaled_data = scaler.transform(data)
X_train, X_test, Y_train, Y_test = train_test_split(scaled_data, dataset.target, random_state=0)
for i in range(0, 5):
    for j in range(0, 2):
        Model =  LogisticRegression(C=c[i],penalty=penalty[j]) 
        scores = cross_val_score(Model, X_train, Y_train, cv=kfolds)
        score = np.mean(scores)
        if score > bestScore:
            bestScore = score
            bestParameter = c[i]
            bestPenalty = penalty[j]
FinalModel = LogisticRegression(penalty=bestPenalty,C=bestParameter).fit(X_train, Y_train)
test_score = FinalModel.score(X_test,Y_test)
PredictedOutput = FinalModel.predict(X_test) 
print("Best Score on train set", bestScore)
print("Best Parameter ", bestParameter)
print("Best Penalty ", bestPenalty)
print("Score of Logistic Regression ", test_score)
confusion=confusion_matrix(Y_test,PredictedOutput)
plt.figure()
plot_confusion_matrix(confusion, classes=dataset.target_names,title='Confusion matrix')
plt.show()
print("Precision is ", precision_score(Y_test,PredictedOutput))
print("Recall is ", recall_score(Y_test,PredictedOutput))
# Out:
# Best Score on train set 0.976525821596
# Best Parameter  100
# Best Penalty  l2
# Score of Logistic Regression  0.958041958042
# Precision is  0.966666666667
# Recall is  0.966666666667

# %% [markdown]
# <h3>  Problem #4  Neural Networks [20 points]</h3>
# In this exercise we will clasify Iris species (Setosa, Versicolor, Virginica) using Neural Networks.<br>
# Use a code below to download the dataset:

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
dataset=load_iris()
print(dataset.keys())
X_train, X_test, Y_train, Y_test = train_test_split(dataset['data'],dataset['target'],random_state=0)
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names'])

# %% [markdown]
# Follow steps to answer questions.
# - Scale the feautures with MinMaxScaler, then use sklearn MLPClassifier.
# - Build a model that has two hidden layers, the first layer has 10 neurons and second layer has 5 neurons.
# - Use 'relu' activation function, and set the regularization parameter alpha=0.5.
# - Set the random_state=0 for splitting and building all models.

# %% [markdown]
# <h4> Problem #4-1 </h4>
# - Use gradient descent to solve the optimization  problem (i.e. get the weights), and choose random_state=0 (which corresponds to a particular initializationo of weight values).
# - Report accuracy, confusion matrix, precision, and recall

# %%
#Write your answer here
from sklearn import preprocessing
from sklearn.neural_network import MLPClassifier
import pylab as plt
import numpy as np
from sklearn.metrics import confusion_matrix, precision_score, recall_score
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
scaler=preprocessing.MinMaxScaler().fit(X_train) #define scaler depending on the features in training data
X_train_transformed=scaler.transform(X_train) #apply scaling on training set
X_test_transformed=scaler.transform(X_test) #apply scaling on test set
MLPmodel=MLPClassifier(solver='sgd',random_state=0, activation = 'relu', hidden_layer_sizes=[10,5], alpha=0.5)
MLPmodel.fit(X_train_transformed, Y_train)
PredictedOutput = MLPmodel.predict(X_test_transformed) # predicted output of classification
print("Accuracy of classifier ", MLPmodel.score(X_test_transformed, Y_test))
confusion=confusion_matrix(Y_test,PredictedOutput)
plt.figure()
plot_confusion_matrix(confusion, classes=dataset.target_names,title='Confusion matrix')
plt.show()


print("Precision of classifier ", precision_score(Y_test,PredictedOutput, average=None))
print("Recall of classifier ", recall_score(Y_test,PredictedOutput, average=None))
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Accuracy of classifier  0.578947368421
# Precision of classifier  [ 0.54166667  0.          0.64285714]
# Recall of classifier  [ 1.  0.  1.]
# C:\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# <h4> Problem #4-2 </h4>
# - Repeat **Problem #4-1** but with a model that use random_state=10 to initialize the weights.
# - Report accuracy, confusion matrix, precision, and recall

# %%
#Write your answer here
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
MLPmodel_2=MLPClassifier(solver='sgd',random_state=10, activation = 'relu', hidden_layer_sizes=[10,5], alpha=0.5)
MLPmodel_2.fit(X_train_transformed, Y_train)
PredictedOutput = MLPmodel_2.predict(X_test_transformed) # predicted output of classification
print("Accuracy of classifier ", MLPmodel_2.score(X_test_transformed, Y_test))
confusion = confusion_matrix(Y_test,PredictedOutput)
confusion=confusion_matrix(Y_test,PredictedOutput)
plt.figure()
plot_confusion_matrix(confusion, classes=dataset.target_names,title='Confusion matrix')
plt.show()
print("Precision of classifier ", precision_score(Y_test,PredictedOutput, average=None))
print("Recall of classifier ", recall_score(Y_test,PredictedOutput, average=None))
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Accuracy of classifier  0.421052631579
# Precision of classifier  [ 0.          0.42105263  0.        ]
# Recall of classifier  [ 0.  1.  0.]
# C:\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# <h4> Problem #4-3 </h4>
# - Repeat **Problem #4-2** but with model that use L-BFGS (a numerical quasi-Newton method) instead of stochastic gradient descent to find the weights.
# - Report accuracy, confusion matrix, precision, and recall
# - Comment on results

# %%
#Write your answer here
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
MLPmodel_3=MLPClassifier(solver='lbfgs',random_state=0, activation = 'relu', hidden_layer_sizes=[10,5], alpha=0.5)
MLPmodel_3.fit(X_train_transformed, Y_train)
PredictedOutput = MLPmodel_3.predict(X_test_transformed) # predicted output of classification
print("Accuracy of classifier ", MLPmodel_3.score(X_test_transformed, Y_test))
confusion = confusion_matrix(Y_test,PredictedOutput)
plt.figure()
plot_confusion_matrix(confusion, classes=dataset.target_names,title='Confusion matrix')
plt.show()
print("Precision of classifier ", precision_score(Y_test,PredictedOutput, average=None))
print("Recall of classifier ", recall_score(Y_test,PredictedOutput, average=None))
# Out:
# Accuracy of classifier  0.973684210526
# Precision of classifier  [ 1.   1.   0.9]
# Recall of classifier  [ 1.      0.9375  1.    ]

# %% [markdown]
# gradient decent model does not work well and has very bad accuracy, recall and precesion. Instead, L-BFGS we get better accuracy and almost perfect recall and precision
